# %% [markdown]
# # Class Notebooks
#
# * [HAPI_00.ipynb](HAPI_00.ipynb) - Introduction
# * [HAPI_01.ipynb](HAPI_01.ipynb) - Basics
# * [HAPI_02.ipynb](HAPI_02.ipynb) - Data structures
# * **[HAPI_03.ipynb](HAPI_03.ipynb) - Plotting (this Notebook)**
# * [HAPI_04.ipynb - Problems](HAPI_04.ipynb)

# %% [markdown]
# # Setup

# %%
# Show Matplotlib plots in page instead of opening a window
# %matplotlib inline 
# Have Matplotlib create vector (svg) instead of raster (png) images
# %config InlineBackend.figure_formats = ['svg'] 

# Misc. configuration
import warnings
# See https://github.com/boto/boto3/issues/454 for an explanation.
warnings.simplefilter("ignore", ResourceWarning) # removes spurious Notebook warns
warnings.simplefilter("ignore", DeprecationWarning) # removes spurious Notebook warns
warnings.filterwarnings(action="ignore", message="unclosed", category=ResourceWarning)

# %%
# !pip install --upgrade hapiclient hapiplot > /dev/null

# %% [markdown]
# # `hapiplot` - Basic
#
# The package `hapiplot` can be used to plot of data returned by the `hapi` function.
#
# Interally, `hapiplot` uses Matplotlib and the functions `timeseries.py` and  `heatmap.py` in the directory [plot](https://github.com/hapi-server/client-python/tree/master/hapiclient/plot).
#
# `hapiplot` plots all of the parameters returned by a call to `hapi` and forms calls to `timeseries.py` and  `heatmap.py` with labels extracted from `meta`.
#
# There are two ways to create a plot using `hapiplot()`
# 1. Using the return values of the `hapi()` function
#     ```Python
#     data, meta = hapi(server, dataset, parameters, start, stop)
#     meta = hapiplot(data, meta)
#     ```
# 2. By passing `server`, `dataset`, ...
#     ```Python
#     data, meta = hapiplot(server,dataset,parameters,start,stop)
#     ```

# %%
server     = 'http://hapi-server.org/servers/TestData2.0/hapi'
dataset    = 'dataset1'
parameters = 'scalar,vector'
start      = '1970-01-01T00:00:00'
stop       = '1970-01-01T00:59:59'
opts       = {'logging': False, 'usecache': True, 'cachedir': './hapicache'}

# Method 1.
from hapiclient import hapi
from hapiplot import hapiplot
data, meta = hapi(server, dataset, parameters, start, stop, **opts)
hapiplot(data, meta)

if False:
    # Method 2.
    from hapiplot import hapiplot
    meta = hapiplot(server, dataset, parameters, start, stop)

# %% [markdown]
# # `hapiplot` - Advanced

# %% [markdown]
# # Matplotlib
#
# The standard package for plotting in Python is Matplotlib. The plotting features of this package are low-level, meaning that a significant amount of configuration is needed to configure a plot.

# %%
from hapiclient import hapi

server     = 'http://hapi-server.org/servers/TestData2.0/hapi'
dataset    = 'dataset1'
parameters = 'scalar'
start      = '1970-01-01T00:00:00'
stop       = '1970-01-01T00:00:10'
opts       = {'logging': False, 'usecache': True, 'cachedir': './hapicache'}

data, meta = hapi(server, dataset, parameters, start, stop, **opts)

from matplotlib import pyplot as plt
from hapiclient import hapitime2datetime

# Convert data['Time'] elements to Python datetime objects
# Note the difference in tick labels when datetimes are used
plt.figure()
plt.plot(hapitime2datetime(data['Time']),data['scalar'])
plt.gcf().autofmt_xdate()
plt.title('scalar with Time as datetimes');

# %% [markdown]
# <div style="background-color:yellow">
# <h3>Problem 03a</h3>
#
# <p>Use the metadata in <code>meta</code> to label the y-axis with the name of the parameter and its units.</p>
# </h3>

# %% [markdown]
# # Pandas
#
# Similarly, we can convert the HAPI numpy data to a Pandas DataFrame like we did earlier, then plot that with the 'df.plot()' approach.

# %%
# Get data for use below
from hapiclient import hapi
from hapiclient import hapitime2datetime

server     = 'http://hapi-server.org/servers/TestData2.0/hapi'
dataset    = 'dataset1'
parameters = 'scalar,vector'
start      = '1970-01-01T00:00:00'
stop       = '1970-01-01T00:00:10'
opts       = {'logging': False, 'usecache': True, 'cachedir': './hapicache'}

data, meta = hapi(server,dataset,parameters,start,stop,**opts)

import pandas
# Create dataframe
df = pandas.DataFrame(data['vector'])

# Add column to DataFrame
df['Time'] = hapitime2datetime(data['Time'])

# Set index
df.set_index('Time', inplace=True)

# Rename columns
df.columns = ['x', 'y', 'z']

display(df)

# %matplotlib inline
df.plot();
# Out:
#                                   x         y         z
# Time
# 1970-01-01 00:00:00+00:00  0.000000 -0.707107 -1.000000
# 1970-01-01 00:00:01+00:00  0.005236 -0.703395 -0.999986
# 1970-01-01 00:00:02+00:00  0.010472 -0.699663 -0.999945
# 1970-01-01 00:00:03+00:00  0.015707 -0.695913 -0.999877
# 1970-01-01 00:00:04+00:00  0.020942 -0.692143 -0.999781
# 1970-01-01 00:00:05+00:00  0.026177 -0.688355 -0.999657
# 1970-01-01 00:00:06+00:00  0.031411 -0.684547 -0.999507
# 1970-01-01 00:00:07+00:00  0.036644 -0.680721 -0.999328
# 1970-01-01 00:00:08+00:00  0.041876 -0.676876 -0.999123
# 1970-01-01 00:00:09+00:00  0.047106 -0.673013 -0.998890

# %% [markdown]
# ## PySPEDAS/PyTplot
#
# PySPEDAS access HAPI servers without needing to install either the `hapiclient` or `hapiplot` packages.
#
# In the following, data from a HAPI server is obtained using the `pyhapi` function in the `pyspedas` package and plotted using the `tplot` function in the `pytplot` package.

# %%
# !pip install pyspedas --upgrade
# Out:
# Requirement already satisfied: pyspedas in /Users/weigel/miniconda3/lib/python3.8/site-packages (1.3.5)
# Requirement already satisfied: pywavelets in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (1.3.0)
# Requirement already satisfied: cdflib>=0.4.3 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (0.4.4)
# Requirement already satisfied: numpy>=1.19.5 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (1.21.2)
# Requirement already satisfied: astropy in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (5.0.4)
# Requirement already satisfied: requests in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (2.25.1)
# Requirement already satisfied: netCDF4 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (1.5.8)
# Requirement already satisfied: geopack>=1.0.9 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (1.0.9)
# Requirement already satisfied: pytplot-mpl-temp>=2.0.2 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (2.0.2)
# Requirement already satisfied: hapiclient>=0.2.2 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (0.2.4)
# Requirement already satisfied: cdasws>=1.7.24 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pyspedas) (1.7.37)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from cdasws>=1.7.24->pyspedas) (2.8.2)
# Requirement already satisfied: attrs>=19.2.0 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from cdflib>=0.4.3->pyspedas) (21.4.0)
# Requirement already satisfied: urllib3 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from hapiclient>=0.2.2->pyspedas) (1.26.6)
# Requirement already satisfied: isodate>=0.6.0 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from hapiclient>=0.2.2->pyspedas) (0.6.1)
# Requirement already satisfied: joblib in /Users/weigel/miniconda3/lib/python3.8/site-packages (from hapiclient>=0.2.2->pyspedas) (1.1.0)
# Requirement already satisfied: pandas>=0.23 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from hapiclient>=0.2.2->pyspedas) (1.4.2)
# Requirement already satisfied: six in /Users/weigel/miniconda3/lib/python3.8/site-packages (from isodate>=0.6.0->hapiclient>=0.2.2->pyspedas) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pandas>=0.23->hapiclient>=0.2.2->pyspedas) (2022.1)
# Requirement already satisfied: xarray in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pytplot-mpl-temp>=2.0.2->pyspedas) (2022.3.0)
# Requirement already satisfied: matplotlib>=3.4 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pytplot-mpl-temp>=2.0.2->pyspedas) (3.4.3)
# Requirement already satisfied: scipy in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pytplot-mpl-temp>=2.0.2->pyspedas) (1.7.1)
# Requirement already satisfied: bokeh>=1.1 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from pytplot-mpl-temp>=2.0.2->pyspedas) (2.4.2)
# Requirement already satisfied: Jinja2>=2.9 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from bokeh>=1.1->pytplot-mpl-temp>=2.0.2->pyspedas) (3.0.3)
# Requirement already satisfied: packaging>=16.8 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from bokeh>=1.1->pytplot-mpl-temp>=2.0.2->pyspedas) (21.3)
# Requirement already satisfied: PyYAML>=3.10 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from bokeh>=1.1->pytplot-mpl-temp>=2.0.2->pyspedas) (6.0)
# Requirement already satisfied: tornado>=5.1 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from bokeh>=1.1->pytplot-mpl-temp>=2.0.2->pyspedas) (6.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from bokeh>=1.1->pytplot-mpl-temp>=2.0.2->pyspedas) (4.1.1)
# Requirement already satisfied: pillow>=7.1.0 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from bokeh>=1.1->pytplot-mpl-temp>=2.0.2->pyspedas) (8.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh>=1.1->pytplot-mpl-temp>=2.0.2->pyspedas) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from matplotlib>=3.4->pytplot-mpl-temp>=2.0.2->pyspedas) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from matplotlib>=3.4->pytplot-mpl-temp>=2.0.2->pyspedas) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from matplotlib>=3.4->pytplot-mpl-temp>=2.0.2->pyspedas) (1.3.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from requests->pyspedas) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from requests->pyspedas) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from requests->pyspedas) (2.10)
# Requirement already satisfied: pyerfa>=2.0 in /Users/weigel/miniconda3/lib/python3.8/site-packages (from astropy->pyspedas) (2.0.0.1)
# Requirement already satisfied: cftime in /Users/weigel/miniconda3/lib/python3.8/site-packages (from netCDF4->pyspedas) (1.6.0)

# %%
# Get data for use below
from hapiclient import hapi
from hapiclient import hapitime2datetime

server     = 'http://hapi-server.org/servers/TestData2.0/hapi'
dataset    = 'dataset1'
parameters = 'scalar,vector'
start      = '1970-01-01T00:00:00'
stop       = '1970-01-01T00:00:10'

data, meta = hapi(server,dataset,parameters,start,stop)

import pandas
# Create dataframe
df = pandas.DataFrame(data['vector'])

# Add column to DataFrame
df['Time'] = hapitime2datetime(data['Time'])

# Set index
df.set_index('Time', inplace=True)

# Rename columns
df.columns = ['x', 'y', 'z']

display(df)

# %matplotlib inline
df.plot();
# Out:
#                                   x         y         z
# Time
# 1970-01-01 00:00:00+00:00  0.000000 -0.707107 -1.000000
# 1970-01-01 00:00:01+00:00  0.005236 -0.703395 -0.999986
# 1970-01-01 00:00:02+00:00  0.010472 -0.699663 -0.999945
# 1970-01-01 00:00:03+00:00  0.015707 -0.695913 -0.999877
# 1970-01-01 00:00:04+00:00  0.020942 -0.692143 -0.999781
# 1970-01-01 00:00:05+00:00  0.026177 -0.688355 -0.999657
# 1970-01-01 00:00:06+00:00  0.031411 -0.684547 -0.999507
# 1970-01-01 00:00:07+00:00  0.036644 -0.680721 -0.999328
# 1970-01-01 00:00:08+00:00  0.041876 -0.676876 -0.999123
# 1970-01-01 00:00:09+00:00  0.047106 -0.673013 -0.998890

# %% [markdown]
# ## PySPEDAS/PyTplot
#
# PySPEDAS access HAPI servers without needing to install either the `hapiclient` or `hapiplot` packages.
#
# In the following, data from a HAPI server is obtained using the `pyhapi` function in the `pyspedas` package and plotted using the `tplot` function in the `pytplot` package.

# %%
# !pip install pyspedas --upgrade > /dev/null

# %%
from pyspedas.hapi.hapi import hapi as pyhapi

server     = 'https://cdaweb.gsfc.nasa.gov/hapi'
dataset    = 'GE_K0_CPI'
parameters = 'SW_P_Den,SW_V'
start      = '1992-09-08T07:30:40Z'
stop       = '1992-09-10T07:30:40.000Z'
opts       = {'logging': False, 'usecache': True, 'cachedir': './hapicache'}

x = pyhapi(trange=[start, stop], server=server, dataset=dataset, parameters=parameters)

from pytplot import tplot
tplot(x)
# Out:
# Loading SW_P_Den
# Loading SW_V

# %% [markdown]
# ----
# Next up, [Problems](HAPI_04.ipynb)
# ----
